# %%
pwd
# Out:
# 'C:\\Users\\akshata'

# %%
name = "akshata"

# %% [markdown]
# name

# %%
name
# Out:
# 'akshata'

# %%
num1 = 12
num2 = 3
num3 = "c"

# %%
num = int(input("enter the no"))

if num > 5:

    print('yes')
# Out:
# enter the no 4

# %%
num = int(input("enter the no"))

if num > 5:
    print('yes')  
else:
    print('no')
# Out:
# enter the no 5
# no

# %%
## write a program to check if the number is +ve or -ve

# %%
num = int(input("enter the no"))
if num > 0:
    print("positive")
elif num == 0:
    print("zero")
else:
    print("negative")
# Out:
# enter the no 0
# zero

# %%
#check if the number is even or odd

# %%
num = int(input("enter the no"))
if num % 2 == 0:
    print("even")
else:

    print("odd")
# Out:
# enter the no 5
# odd

# %%
True + True + False
# Out:
# 2

# %%
a = 1
if a:
    print('exists')
# Out:
# exists

# %%
#check id the number is in between 50 and 100 or not (use nested if)

# %%
num = int(input("enter the no"))
if num  >50 :
    if num < 100:
        print("condition satisfield")
    else:
        print("greater than 50 but not less than 100")
else:
    print("number is less then 50")
# Out:
# enter the no 50
# number is less then 50

# %%
# do the same with logical operator

# %%
num = int(input("enter the no"))
if num >= 50 and  num <= 100:
    print("satisfild")
else:
    print (" not satisfild")
# Out:
# enter the no 500
#  not satisfild

# %%
# read purchase cost and selling cost from the use
# state profit or loss and how much

# %%
selling_cost = int(input("enter the selling cost"))
purchase_cost = int(input("enter the purchase cost"))
if selling_cost > purchase_cost:
    print(f"profit of => {selling_cost - purchase_cost}")
else:
    print(f"loss of => {purchase_cost - selling_cost} and ur time")
# Out:
# enter the selling cost 8000
# enter the purchase cost 70000
# loss of => 62000 and ur time

# %%
"""" 
2020 ->leap
2017 -> not leap
2000 -> leap
1800 -> not leap
"""";

# %%
#use nested if only (and or not allowed)

# %% [raw]
# num = int(input("Enter a number: "))
#
# if num > 0:
#     if num % 2 == 0:
#         print("Positive Even Number")
#     else:
#         print("Positive Odd Number")
# else:
#     print("Not Positive")

# %%
year = int(input("Enter year: "))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("century leap")
        else:
            print("century is not leap")
    else:
        print("leap")
else:
    print("not leap")
# Out:
# Enter year:  1800
# century is not leap

# %%
""" 
take 3 numbers
find which one is largset(use nested if only)
""";

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b:
    if a > c:
        print("Largest number is:", a)
    else:
        print("Largest number is:", c)
else:
    if b > c:
        print("Largest number is:", b)
    else:
        print("Largest number is:", c)
# Out:
# Enter first number:  45
# Enter second number:  56
# Enter third number:  78
# Largest number is: 78

# %%
#menu driven

# %%
print("welcome to the simplest calculator")

num = int(input("enter the number"))

print("Menu =>\n1. square\n2.cube\n3. check +ve or -ve")

ch = int(input("select ur choice"))

if ch == 1:
    print(num * num)
elif ch == 2:
    print (num ** 3)
elif ch == 3:
    if num > 0:
        print("positive")
    elif num == 0:
        print("zero")
    else:
        print(negative")
# Out:
#   Cell In[82], line 19
#     print(negative")
#                   ^
# SyntaxError: unterminated string literal (detected at line 19)

# %%
print("welcome to the simplest calculator")

num = int(input("enter the number: "))

print("Menu =>\n1. square\n2. cube\n3. check +ve or -ve")

ch = int(input("select ur choice: "))

if ch == 1:
    print(num * num)

elif ch == 2:
    print(num ** 3)

elif ch == 3:
    if num > 0:
        print("positive")
    elif num == 0:
        print("zero")
    else:
        print("negative")

else:
    print("Invalid choice")
# Out:
# welcome to the simplest calculator
# enter the number:  7
# Menu =>
# 1. square
# 2. cube
# 3. check +ve or -ve
# select ur choice:  32523
# Invalid choice

# %% [markdown]
# """
# menu driven ->
# take a string from the usr
# menu-> upper, lowercase,3replace aparticular part of the string
# for third option it should which part to replace with what
# """;

# %%
s = input("Enter a string: ")

print("\nMENU")
print("1. Convert to Uppercase")
print("2. Convert to Lowercase")
print("3. Replace part of string")

ch = int(input("Enter your choice: "))

if ch == 1:
    print("Uppercase String:", s.upper())

elif ch == 2:
    print("Lowercase String:", s.lower())

elif ch == 3:
    old = input("Enter word/part to replace: ")
    new = input("Enter new word/part: ")

    result = s.replace(old, new)

    print("Updated String:", result)

else:
    print("Invalid Choice")
# Out:
# Enter a string:  wer
# MENU
# 1. Convert to Uppercase
# 2. Convert to Lowercase
# 3. Replace part of string
# Enter your choice:  2
# Lowercase String: wer
