# %%
#string function

# %%
name = "Akshata"

# %%
name.lower()
# Out:
# 'akshata'

# %%
name
# Out:
# 'Akshata'

# %%
name = name.lower()

# %%
name
# Out:
# 'akshata'

# %%
name.upper()
# Out:
# 'AKSHATA'

# %%
name.title()
# Out:
# 'Akshata'

# %%
name = "Akshata"

# %%
name.swapcase()
# Out:
# 'aKSHATA'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name2.isalnum()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name = " pune "

# %%
print(name)
# Out:
#  pune

# %%
name.startswith("p")
# Out:
# False

# %%
name.startswith(" p")
# Out:
# True

# %%
name.endswith(" pune ")
# Out:
# True

# %%
 name.lstrip()
# Out:
# 'pune '

# %%
name.strip()
# Out:
# 'pune'

# %%
name.rstrip()
# Out:
# ' pune'

# %%
name.strip()
# Out:
# 'pune'

# %%
len(name)
# Out:
# 6

# %%
name.replace('u','oo')
# Out:
# ' poone '

# %% [markdown]
# operator

# %%
#arithmetic

# %%
a = 5
b = 17

# %%
a + b
# Out:
# 22

# %%
a - b
# Out:
# -12

# %%
a * b
# Out:
# 85

# %%
a / b
# Out:
# 0.29411764705882354

# %%
a ** b #raise to
# Out:
# 762939453125

# %%
a // b#floor div
# Out:
# 0

# %%
a // b #floor div
# Out:
# 0

# %%
b % a
# Out:
# 2

# %%
## assignment operator

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z + 3
z
# Out:
# 8

# %%
z += 3
z
# Out:
# 11

# %%
z -= 3
z
# Out:
# 8

# %%
z *= 3
z
# Out:
# 24

# %%
z /= 3
z
# Out:
# 8.0

# %%
z %= 3
z
# Out:
# 2.0

# %%
z //= 3
z
# Out:
# 0.0

# %%
z
# Out:
# 0.0

# %%
z %= 3

# %%
z
# Out:
# 0.0

# %%
# comparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# logical operator

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
not a and b
# Out:
# False

# %%
# identity operator -> is, is not

# %%
a = 5
b = 5

# %%
id(a), id(b)
# Out:
# (140732451038248, 140732451038248)

# %%
a is b
# Out:
# True

# %%
a = [3,4]
b = [3,4]

# %%
 id(a), id(b)
# Out:
# (1806064320320, 1806064151616)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)
a
# Out:
# [3, 4, 10, 10]

# %%
z
# Out:
# [3, 4, 10, 10]

# %%
#membership selection operator -> in

# %%
l = [4, 6, 19, 10]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %% [markdown]
# precedence and association

# %%
# BODMAS

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3 # right association
# Out:
# 256

# %%
2 ** 3 / 2
# Out:
# 4.0

# %%
# print function

# %%
name = "Geet"
marks = 76.57

# %%
print ("my name is",name, "and marks are", marks)
# Out:
# my name is Geet and marks are 76.57

# %%
print("my name is %s and marks are %i"%(name,marks))
# Out:
# my name is Geet and marks are 76

# %%
print(f"my name is {name} and marks are{marks}")
# Out:
# my name is Geet and marks are76.57

# %%
# dir and help

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(35)
# Out:
# '#'

# %%
# typecasting

# %%
num1 = 34
num2 = 44.56
num3 = "ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num1)
# Out:
# '34'

# %%
str(num2)
# Out:
# '44.56'

# %%
#user input

# %%
a = input("enter the number")
# Out:
# enter the number 45

# %%
print("ok")
# Out:
# ok

# %%
# write a program for addition of 2 numbers using user input

# %%
a = int(input("enter the  1st number:"))
b = int(input("enter the 2nd number"))
z = a + b
print("addition is =>",z)
# Out:
# enter the  1st number: 5
# enter the 2nd number 9
# addition is => 14

# %%
""" 

read the time in seconds as user input 
and print the time in the format as hour: minute :seconds

eg...
input -> 125seconds
output->00:02:05

""";
